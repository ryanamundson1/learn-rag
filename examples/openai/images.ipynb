# %%
from dotenv import load_dotenv

load_dotenv(override=True)

from openai import OpenAI

client = OpenAI()

response = client.images.generate(
  model="dall-e-3",
  prompt="a white siamese cat",
  size="1024x1024",
  quality="standard",
  n=1,
)

image_url = response.data[0].url

# %%
image_url
# Out:
# 'https://oaidalleapiprodscus.blob.core.windows.net/private/org-3UlIZd2a84RawVWIurtNraL9/user-8bOn1ZgUrcNKMHpD2JzGik9a/img-1xbhwNMcuEc8bZC5iD5e7hzS.png?st=2025-02-05T21%3A07%3A33Z&se=2025-02-05T23%3A07%3A33Z&sp=r&sv=2024-08-04&sr=b&rscd=inline&rsct=image/png&skoid=d505667d-d6c1-4a0a-bac7-5c84a87759f8&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2025-02-05T21%3A09%3A18Z&ske=2025-02-06T21%3A09%3A18Z&sks=b&skv=2024-08-04&sig=q8cuCP%2BdIcNeGXcM8YhsQPTUQ/640ghmEIfkJaK/4WE%3D'

# %%
from skimage import io
import matplotlib.pyplot as plt
from PIL import Image

# Parse response object to get base64 string for image
img_base64 = image_url

image = io.imread(img_base64)

# Display image
plt.imshow(image)
plt.title("Image")
plt.axis('off')
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.
